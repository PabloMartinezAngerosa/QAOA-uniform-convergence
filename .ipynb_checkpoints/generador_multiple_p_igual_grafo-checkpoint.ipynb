# %%
from tsp_qaoa import test_solution
from qiskit.visualization import plot_histogram
import networkx as nx
import numpy as np
import json
import csv
# Array of JSON Objects

# %%
header = ['p', 'state', 'probability', 'mean']
length_p = 10

with open('qaoa_multiple_p.csv', 'w', encoding='UTF8') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)
    first_p = False
    
    for p in range(length_p):
        p = p+1
        if first_p == False:
            job_2, G, UNIFORM_CONVERGENCE_SAMPLE = test_solution(p=p)
            first_p = True
        else:
            job_2, G, UNIFORM_CONVERGENCE_SAMPLE = test_solution(grafo=G, p=p)
            
        # Sort the JSON data based on the value of the brand key
        UNIFORM_CONVERGENCE_SAMPLE.sort(key=lambda x: x["mean"])


        mean = UNIFORM_CONVERGENCE_SAMPLE[0]["mean"]
        print(mean)
        state = 0
        for probability in UNIFORM_CONVERGENCE_SAMPLE[0]["probabilities"]:
            state += 1
            writer.writerow([p,state, probability,mean])
# Out:
# 0.5641209626668292
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 19.39073767197884
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 41
#   status: 1
#  success: True
#        x: array([3.28316517, 1.64124171])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 19.272993438285503
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 16
# El vector minimo es 0110
#      fun: 12.856563894399113
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 79
#   status: 1
#  success: True
#        x: array([1.038633  , 0.38269139, 3.43554681, 1.80631443])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 12.744953520238045
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 16
# El vector minimo es 0110
#      fun: 6.661372791944792
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 173
#   status: 1
#  success: True
#        x: array([1.84743149, 2.71068564, 0.15306823, 5.99506683, 0.55539526,
#        5.73402779])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 6.41673719992506
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 16
# El vector minimo es 1001
#      fun: 9.910849306573587
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 141
#   status: 1
#  success: True
#        x: array([3.02055356, 0.96233104, 1.09733072, 2.08679735, 5.70030229,
#        0.95039728, 1.45671768, 2.18648877])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 9.51457250492719
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 16
# El vector minimo es 1001
#      fun: 2.686703739773661
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 297
#   status: 1
#  success: True
#        x: array([0.88661296, 1.9529318 , 0.16243463, 1.16031593, 2.10241394,
#        2.22252402, 5.56797002, 2.92057122, 4.74498871, 5.46239171])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.6404472559229935
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 16
# El vector minimo es 0110
#      fun: 2.478005041734716
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 384
#   status: 1
#  success: True
#        x: array([0.74424595, 1.67925977, 2.87288773, 1.84418633, 1.4138544 ,
#        1.52544454, 5.87006536, 5.44991345, 4.81712784, 1.08256315,
#        3.91760108, 0.56666572])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.4076665691571164
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 16
# El vector minimo es 0110
#      fun: 1.6464976916403193
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 243
#   status: 1
#  success: True
#        x: array([0.03357476, 3.66487099, 2.55795808, 2.26285403, 1.6399221 ,
#        2.24900585, 1.91677412, 4.16218915, 5.4973754 , 1.64121329,
#        5.46198559, 2.23913865, 1.25218132, 4.27815007])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.7553694497149857
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 16
# El vector minimo es 0110
#      fun: 2.20211786592725
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 200
#   status: 1
#  success: True
#        x: array([2.54837987, 1.33962665, 0.79947682, 4.11694804, 2.40533183,
#        2.69414893, 2.36701064, 1.7068192 , 4.10477986, 1.98919155,
#        4.13887548, 3.84061942, 0.59994796, 1.7191666 , 6.62426072,
#        4.80745885])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.236876799809383
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 14
# El vector minimo es 0110
#      fun: 1.3272776608621903
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 260
#   status: 1
#  success: True
#        x: array([1.69072473, 0.38028699, 2.75392681, 1.82202634, 2.10312204,
#        1.1421953 , 2.12950089, 2.74912337, 2.10874929, 3.20985989,
#        0.17870972, 5.62761104, 4.29192751, 4.06717503, 4.31629527,
#        3.55633127, 1.19478641, 0.07914593])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.34992377055179
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 15
# El vector minimo es 0110
#      fun: 1.3835341447128575
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 273
#   status: 1
#  success: True
#        x: array([2.74407862, 1.58458695, 2.76408046, 3.19983723, 2.55452988,
#        2.48909759, 0.86125994, 2.15547254, 1.91369673, 1.49364277,
#        3.42691259, 5.57261513, 0.36699865, 1.48099613, 2.64165073,
#        2.71438412, 5.89510983, 2.00754531, 0.65787938, 2.01300267])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.385646968905391
# El valor minimo de todos los evaluados es 1.1282419253336584 se evaluaron un total de 14
# El vector minimo es 1001
