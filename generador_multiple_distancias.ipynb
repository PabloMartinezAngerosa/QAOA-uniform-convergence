# %%
from tsp_qaoa import test_solution
from qiskit.visualization import plot_histogram
import networkx as nx
import numpy as np
import json
import csv
# Array of JSON Objects

# %%
header = ['instance', 'iteration', 'distance']
length_instances = 40

with open('qaoa_multiple_distance.csv', 'w', encoding='UTF8') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)
    
    
    for instance in range(length_instances):
        
        job_2, G, UNIFORM_CONVERGENCE_SAMPLE = test_solution()
        # Sort the JSON data based on the value of the brand key
        UNIFORM_CONVERGENCE_SAMPLE.sort(key=lambda x: x["mean"])
        index = -1
        for sample in UNIFORM_CONVERGENCE_SAMPLE:
            mean = sample["mean"]
            index += 1
            distance_p_ground_state = np.max(np.abs(UNIFORM_CONVERGENCE_SAMPLE[0]["probabilities"] - sample["probabilities"]))
            UNIFORM_CONVERGENCE_SAMPLE[index]["distance_pgs"] = distance_p_ground_state

        
        iteration = 0
        for sample in UNIFORM_CONVERGENCE_SAMPLE:
            iteration += 1
            mean = sample["mean"]
            distance = sample["distance_pgs"]
            writer.writerow([instance,iteration, distance])
# Out:
# 0.17350119260203797
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 0.7267941837729535
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 267
#   status: 1
#  success: True
#        x: array([2.50393611, 1.50779547, 0.844999  , 2.33161148, 3.20394229,
#        1.40529252, 3.24344731, 5.78835868, 2.3221934 , 3.8185998 ,
#        2.39702685, 6.28591087, 5.81976703, 2.32676032])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 0.6627247832959127
# El valor minimo de todos los evaluados es 0.34700238520407595 se evaluaron un total de 14
# El vector minimo es 1001
# 0.11750247172769798
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 0.6837853757300572
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 189
#   status: 1
#  success: True
#        x: array([3.55888811, 1.5001507 , 1.00846185, 2.69818487, 2.82352797,
#        2.88877868, 1.44278397, 0.94181894, 0.32409037, 0.56965399,
#        1.81991834, 1.82059987, 3.05114954, 1.78303525])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 0.6641378831452401
# El valor minimo de todos los evaluados es 0.23500494345539596 se evaluaron un total de 16
# El vector minimo es 0110
# 0.5122762400263554
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 4.971362496619286
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 173
#   status: 1
#  success: True
#        x: array([ 1.41967693,  3.29796671, -0.08252924,  2.05069522,  1.78776265,
#         1.43580664,  0.99936309,  7.08722127,  5.83551392,  6.39684126,
#         2.60239008,  2.90828646,  2.87879982,  4.85435691])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 4.940694414843354
# El valor minimo de todos los evaluados es 1.0245524800527108 se evaluaron un total de 16
# El vector minimo es 0110
# 0.3201600511931364
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.635306596625229
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 257
#   status: 1
#  success: True
#        x: array([1.58985144, 3.30915915, 1.27545847, 0.76727893, 2.77000966,
#        0.71477358, 1.13337501, 3.06999649, 3.19507533, 4.59575286,
#        6.75018223, 2.89441668, 0.4561618 , 5.58957843])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.6501540204409335
# El valor minimo de todos los evaluados es 0.6403201023862728 se evaluaron un total de 16
# El vector minimo es 1001
# 0.11619320087696891
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 5.2631783849433
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 189
#   status: 1
#  success: True
#        x: array([2.74494312, 2.58177862, 2.77579007, 2.3670144 , 2.65738469,
#        2.21209974, 2.96675961, 5.74496597, 5.60493396, 4.94772339,
#        3.74317725, 2.33759277, 7.14682603, 4.17923875])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 5.0365509416585645
# El valor minimo de todos los evaluados es 0.23238640175393782 se evaluaron un total de 16
# El vector minimo es 0110
# 0.7382163875170076
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 4.575266411973389
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 322
#   status: 1
#  success: True
#        x: array([0.44693477, 2.99243837, 2.63016141, 1.10303772, 0.51153618,
#        3.04191607, 2.43524122, 2.58263448, 2.80049057, 4.45326675,
#        5.90125352, 1.65416612, 4.05484161, 0.36312214])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 4.548622464485736
# El valor minimo de todos los evaluados es 1.4764327750340152 se evaluaron un total de 16
# El vector minimo es 1001
# 0.7998109376181655
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 6.511370013318744
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 272
#   status: 1
#  success: True
#        x: array([1.65984477, 2.24107215, 2.38289306, 1.9869061 , 0.65941694,
#        0.55184173, 1.37479323, 3.45578055, 4.39680179, 1.3570393 ,
#        3.93278847, 6.09055999, 1.7382168 , 3.47526662])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 6.476090315818555
# El valor minimo de todos los evaluados es 1.599621875236331 se evaluaron un total de 16
# El vector minimo es 0110
# 0.5369572013071353
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.6481822189154482
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 218
#   status: 1
#  success: True
#        x: array([1.75109872, 2.8534123 , 2.94948493, 2.03884818, 2.64714004,
#        2.87137977, 0.26010922, 1.20031142, 2.32951976, 2.0775126 ,
#        4.86954345, 7.19223509, 4.68354282, 1.82462477])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.6198600445946636
# El valor minimo de todos los evaluados es 1.0739144026142706 se evaluaron un total de 15
# El vector minimo es 0110
# 0.9907085201527602
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 3.1602407317865544
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 225
#   status: 1
#  success: True
#        x: array([3.48950032, 1.33950229, 2.95528521, 0.40503236, 1.86326415,
#        0.93298651, 2.97677469, 1.06632456, 3.35718392, 6.27400833,
#        0.27561413, 1.43545974, 1.99018622, 0.03586288])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 3.0859868412034404
# El valor minimo de todos los evaluados es 1.9814170403055205 se evaluaron un total de 16
# El vector minimo es 0110
# 0.8534469379692422
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 2.536002567001302
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 269
#   status: 1
#  success: True
#        x: array([2.86802704, 3.00626041, 0.97857599, 0.97024808, 3.88951095,
#        2.97353739, 1.97651486, 4.12885811, 5.00184193, 5.44441793,
#        5.31393692, 4.55136973, 3.95713195, 3.07090113])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.495928422915961
# El valor minimo de todos los evaluados es 1.7068938759384844 se evaluaron un total de 16
# El vector minimo es 0110
# 0.21899038934911344
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 3.5674969798326646
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 265
#   status: 1
#  success: True
#        x: array([2.64161019, 0.0426552 , 1.54450993, 3.09363276, 0.70168357,
#        3.19579031, 3.30732525, 1.76171701, 4.52977039, 4.67693442,
#        1.77306778, 1.4398489 , 5.04602723, 4.23892982])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 3.4419349606113623
# El valor minimo de todos los evaluados es 0.4379807786982269 se evaluaron un total de 16
# El vector minimo es 0110
# 0.9695341660256755
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 2.33603212690917
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 320
#   status: 1
#  success: True
#        x: array([0.52314722, 2.93059704, 2.20130063, 2.407841  , 0.88865398,
#        2.70739053, 0.58206646, 0.90137417, 3.57494805, 4.21010514,
#        5.92953293, 0.22160725, 3.5417632 , 0.49769127])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.3115833815748115
# El valor minimo de todos los evaluados es 1.939068332051351 se evaluaron un total de 13
# El vector minimo es 0110
# 0.7798413902715442
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 2.688011662687882
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 206
#   status: 1
#  success: True
#        x: array([ 3.68692697,  1.73062787,  0.56300492,  0.97614689, -0.03516309,
#         1.2159162 ,  2.06762931,  6.63913437,  2.31592972,  2.41796079,
#         1.4790945 ,  6.00883897,  4.00692432,  4.29477012])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.5817549013611854
# El valor minimo de todos los evaluados es 1.5596827805430884 se evaluaron un total de 16
# El vector minimo es 1001
# 0.42115738140451325
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 2.493062894862126
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 279
#   status: 1
#  success: True
#        x: array([1.89281352, 1.96167165, 1.11328565, 0.13980656, 1.20379779,
#        2.91366281, 2.23271259, 2.53019968, 2.70176556, 5.72572883,
#        4.35350423, 4.30303189, 1.26690298, 1.09962823])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.4780736725774966
# El valor minimo de todos los evaluados es 0.8423147628090265 se evaluaron un total de 16
# El vector minimo es 0110
# 0.8156959510902472
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.7711926129522086
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 274
#   status: 1
#  success: True
#        x: array([1.27944744, 2.79518737, 2.96144698, 3.76922896, 1.26389046,
#        1.93982942, 0.07339094, 4.64140004, 1.17924852, 3.84751413,
#        5.30911207, 1.35764074, 4.08382408, 4.7726153 ])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.79302947376199
# El valor minimo de todos los evaluados es 1.6313919021804943 se evaluaron un total de 16
# El vector minimo es 0110
# 0.08352528960692282
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.0925615255835592
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 222
#   status: 1
#  success: True
#        x: array([2.84046539, 2.23109704, 0.78384384, 1.3796114 , 2.32429334,
#        3.56038146, 1.75302335, 5.19476307, 5.74201073, 4.77388949,
#        2.42733439, 2.99457819, 3.71270197, 3.48768669])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.1181438991355248
# El valor minimo de todos los evaluados es 0.16705057921384564 se evaluaron un total de 15
# El vector minimo es 0110
# 0.3857442501897266
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 0.938865439478163
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 434
#   status: 1
#  success: True
#        x: array([1.47663164, 0.60259147, 1.33786543, 1.36392884, 0.76187847,
#        0.74127119, 2.07130953, 5.69414706, 2.01097277, 4.0926994 ,
#        0.34317593, 0.14940227, 7.26754534, 2.43776341])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 0.9710968860282768
# El valor minimo de todos los evaluados es 0.7714885003794532 se evaluaron un total de 13
# El vector minimo es 1001
# 0.36291571040317316
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.2684035395214286
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 340
#   status: 1
#  success: True
#        x: array([3.98328048, 3.67927484, 3.3159966 , 1.82248116, 3.67880865,
#        3.46579801, 2.80886268, 3.88380432, 3.01050548, 3.50789197,
#        4.23844706, 4.34433338, 2.50288907, 4.46045175])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.243822874384784
# El valor minimo de todos los evaluados es 0.7258314208063463 se evaluaron un total de 15
# El vector minimo es 0110
# 0.33545045593652933
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 4.00288783855784
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 250
#   status: 1
#  success: True
#        x: array([0.69109002, 2.74721323, 0.61332947, 4.07428681, 2.19105649,
#        0.53296534, 2.20187394, 6.27903196, 0.60238538, 4.80993674,
#        3.02334777, 0.29027114, 1.20393469, 0.21055407])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 3.9668207484666533
# El valor minimo de todos los evaluados es 0.6709009118730587 se evaluaron un total de 16
# El vector minimo es 0110
# 0.713617537644691
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 2.297576649142286
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 266
#   status: 1
#  success: True
#        x: array([2.63980408, 2.50253052, 1.2314446 , 1.93256798, 1.8112195 ,
#        2.21226049, 0.92893079, 2.06994136, 5.42703132, 4.12934158,
#        2.46785666, 5.4232366 , 1.58151428, 6.16946297])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.300718437202517
# El valor minimo de todos los evaluados es 1.427235075289382 se evaluaron un total de 12
# El vector minimo es 0110
# 0.13797404842630498
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 4.104424145298106
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 309
#   status: 1
#  success: True
#        x: array([2.2721361 , 1.60724341, 1.92134446, 0.32991806, 2.93537276,
#        0.04923935, 2.77428395, 4.48555821, 4.96692423, 2.0774367 ,
#        7.1096031 , 4.8627772 , 1.59342977, 2.55535874])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 4.0366449037755885
# El valor minimo de todos los evaluados es 0.27594809685260996 se evaluaron un total de 16
# El vector minimo es 1001
# 0.4618662112107271
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.578772217923966
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 257
#   status: 1
#  success: True
#        x: array([3.31237683, 0.25130445, 1.60020283, 0.85052957, 0.20227175,
#        0.66080023, 0.17684139, 2.84781412, 1.26016402, 5.41671782,
#        4.28448642, 3.08371329, 4.95744529, 1.1455415 ])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.595511203861903
# El valor minimo de todos los evaluados es 0.9237324224214541 se evaluaron un total de 12
# El vector minimo es 1001
# 0.11421916184650384
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.6247422815199257
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 243
#   status: 1
#  success: True
#        x: array([ 2.11105313,  2.9912887 ,  1.51003925,  0.25563081, -0.15739335,
#         2.07330839,  2.89635581,  2.2618124 ,  3.68662482,  0.07395018,
#         3.53085996,  1.20162144,  4.89074093,  1.53082743])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.5602854048725396
# El valor minimo de todos los evaluados es 0.22843832369300768 se evaluaron un total de 15
# El vector minimo es 0110
# 0.16935650062625632
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.122174247035729
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 301
#   status: 1
#  success: True
#        x: array([2.18644098, 2.13789332, 2.73117629, 2.03306853, 2.23896496,
#        1.23175297, 1.53564362, 1.12265136, 1.26966621, 5.83295182,
#        2.68925193, 3.03934036, 2.07409828, 5.75008474])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.109225850632222
# El valor minimo de todos los evaluados es 0.33871300125251264 se evaluaron un total de 16
# El vector minimo es 0110
# 0.44999951769580815
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 2.6254391110169135
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 245
#   status: 1
#  success: True
#        x: array([1.27712443, 2.57094299, 2.1568772 , 2.28637133, 4.07790616,
#        1.95396951, 1.13905832, 4.79226266, 4.27498766, 5.89260496,
#        2.50086849, 1.45371837, 3.16987353, 4.61867098])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.6535491130425912
# El valor minimo de todos los evaluados es 0.8999990353916163 se evaluaron un total de 12
# El vector minimo es 0110
# 0.8847460045067088
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 5.407055330947934
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 294
#   status: 1
#  success: True
#        x: array([2.20994655, 3.0908194 , 1.26864619, 3.4257609 , 3.50074816,
#        1.75066849, 0.66521332, 4.00060905, 4.29612302, 5.19501268,
#        1.58313346, 1.23190347, 2.52885614, 3.41322546])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 5.537639737340723
# El valor minimo de todos los evaluados es 1.7694920090134176 se evaluaron un total de 16
# El vector minimo es 0110
# 0.2770611426769746
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.9107125260483833
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 297
#   status: 1
#  success: True
#        x: array([2.51881248, 0.73434497, 1.96738724, 2.37719341, 3.11829035,
#        1.96844977, 2.82773989, 5.7204758 , 5.57450366, 2.92769193,
#        3.1491601 , 4.87596678, 1.33079029, 1.12096611])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.8482086562188393
# El valor minimo de todos los evaluados es 0.5541222853539493 se evaluaron un total de 16
# El vector minimo es 0110
# 0.8912129197926367
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 2.904300341916471
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 504
#   status: 1
#  success: True
#        x: array([ 2.05440476,  2.51705333,  1.60764519,  1.86553794,  1.20176437,
#         3.4600561 ,  2.51040615, -0.00909577,  0.47225191,  3.10840576,
#         5.78546951,  0.75500267,  2.79565089,  2.71257574])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.9158049457410518
# El valor minimo de todos los evaluados es 1.7824258395852735 se evaluaron un total de 16
# El vector minimo es 0110
# 0.2608061595492207
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 0.9558045491690227
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 250
#   status: 1
#  success: True
#        x: array([3.58318529, 2.74000485, 1.18896293, 1.75285171, 0.34816485,
#        2.17246685, 0.50713338, 4.67030072, 3.40106123, 2.30779241,
#        0.74461776, 1.43193763, 5.56665639, 1.03811213])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 0.9831786143861045
# El valor minimo de todos los evaluados es 0.5216123190984414 se evaluaron un total de 15
# El vector minimo es 1001
# 0.16867174537833687
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.2016327123583503
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 268
#   status: 1
#  success: True
#        x: array([1.07890263, 0.37179348, 1.03419814, 0.3081866 , 1.80975666,
#        3.25892039, 1.83472984, 1.22506178, 4.1604674 , 5.37646163,
#        5.08943389, 3.96284331, 5.67247634, 0.48839288])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.1432279001694423
# El valor minimo de todos los evaluados es 0.33734349075667375 se evaluaron un total de 16
# El vector minimo es 0110
# 0.08231371842621933
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.5760347780797699
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 328
#   status: 1
#  success: True
#        x: array([0.75899836, 1.69444681, 3.93141537, 3.41434822, 1.02548273,
#        2.39470169, 2.45555667, 4.40995414, 2.09423525, 6.1955999 ,
#        0.74423925, 4.65584876, 0.78709525, 4.48610614])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.4221664800292517
# El valor minimo de todos los evaluados es 0.16462743685243866 se evaluaron un total de 15
# El vector minimo es 1001
# 0.9048889326610664
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 2.216710487299231
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 281
#   status: 1
#  success: True
#        x: array([2.42660973, 0.631051  , 2.91586433, 0.88536233, 0.42659083,
#        2.76408189, 1.89823555, 3.70870062, 5.17820347, 1.90619236,
#        5.28421536, 3.25065998, 1.64122338, 5.29244975])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.2147104872992305
# El valor minimo de todos los evaluados es 1.8097778653221328 se evaluaron un total de 16
# El vector minimo es 1001
# 0.5523177336020191
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 5.713827793828078
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 326
#   status: 1
#  success: True
#        x: array([3.88472073, 1.36057978, 2.98720306, 1.43108485, 3.15205044,
#        1.85851506, 2.13482287, 0.50219393, 5.29538688, 1.23252763,
#        2.60184073, 0.78692943, 5.48848365, 6.22381576])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 5.807310444571574
# El valor minimo de todos los evaluados es 1.1046354672040382 se evaluaron un total de 16
# El vector minimo es 0110
# 0.37381019535338533
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 3.1682946345167196
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 219
#   status: 1
#  success: True
#        x: array([4.15545293, 1.58119304, 1.27030038, 3.61335534, 3.56348437,
#        3.3473493 , 0.05340559, 2.40076308, 1.08729512, 5.9041026 ,
#        7.25757334, 0.70661915, 5.73968342, 4.36374874])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 3.227117016946497
# El valor minimo de todos los evaluados es 0.7476203907067707 se evaluaron un total de 16
# El vector minimo es 1001
# 0.09204371840555516
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 0.5958231613383337
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 260
#   status: 1
#  success: True
#        x: array([2.4384951 , 1.35149676, 2.69655307, 2.18970318, 1.25239879,
#        2.92569733, 1.50613472, 1.91793908, 4.1614168 , 4.18285533,
#        2.69050955, 6.15195197, 6.09218787, 1.99808355])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 0.6439152050567393
# El valor minimo de todos los evaluados es 0.1840874368111103 se evaluaron un total de 16
# El vector minimo es 0110
# 0.31222417652301576
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 4.817409078982678
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 241
#   status: 1
#  success: True
#        x: array([ 3.97204425,  1.59019315,  0.21660539,  1.7199428 ,  2.87294724,
#         0.32446458,  2.64182361,  1.52591788,  4.98893491, -0.01571415,
#         4.90860942,  2.80835455,  1.37850665,  4.17722632])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 4.618031762065471
# El valor minimo de todos los evaluados es 0.6244483530460315 se evaluaron un total de 16
# El vector minimo es 0110
# 0.38705101433018524
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 2.0171745247817423
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 196
#   status: 1
#  success: True
#        x: array([1.63147573, 1.53877125, 0.6034567 , 0.47949864, 0.17296509,
#        1.36402883, 1.24310973, 2.74308723, 5.54380102, 1.62908392,
#        5.7935663 , 5.91593132, 0.69339743, 0.18870293])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 2.0177938064046708
# El valor minimo de todos los evaluados es 0.7741020286603705 se evaluaron un total de 16
# El vector minimo es 1001
# 0.7941448976887893
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 3.524585070118343
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 263
#   status: 1
#  success: True
#        x: array([1.02109205, 4.00364755, 3.89039458, 2.86195113, 2.3598196 ,
#        3.09057769, 2.75714783, 4.61819646, 4.86885843, 1.78946096,
#        4.67119932, 5.24567732, 4.29733754, 2.2725991 ])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 3.4772496615480493
# El valor minimo de todos los evaluados es 1.5882897953775785 se evaluaron un total de 16
# El vector minimo es 0110
# 0.5334388478081512
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 4.726216993676343
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 442
#   status: 1
#  success: True
#        x: array([1.99079952, 2.61141356, 0.50147411, 2.28423571, 2.95742945,
#        1.68836409, 1.19990017, 0.98266188, 1.77790745, 5.15102579,
#        0.60892129, 3.65996415, 2.988165  , 1.88346141])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 4.6310704958328355
# El valor minimo de todos los evaluados es 1.0668776956163024 se evaluaron un total de 12
# El vector minimo es 0110
# 0.25668389293879346
# [0, 1]
# [(0, 1)]
# [0, 1]
#      fun: 1.635618066675758
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 250
#   status: 1
#  success: True
#        x: array([2.46201768, 0.95203601, 2.7373433 , 0.93923045, 2.73071324,
#        3.08414501, 2.95026526, 3.15129998, 4.21314265, 4.09258904,
#        0.23871836, 2.9045385 , 0.81685839, 2.24771124])
# *************************
# En el algoritmo 2 (Marina) el valor esperado como resultado es 1.648385983989652
# El valor minimo de todos los evaluados es 0.5133677858775869 se evaluaron un total de 16
# El vector minimo es 0110
